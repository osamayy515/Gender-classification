# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('male_and_female_small_2.h5')

# %%
import math
from random import randint
predlist =[]

for i in range(10):
    img_path = f'/home/osami/prediction data/{randint(1,102)}.jpg'
    
    from tensorflow.keras.preprocessing import image
    import numpy as np
    
    img = image.load_img(img_path, target_size=(150,150))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.
    
    predlist.append(model.predict(img_tensor))
    
    import matplotlib.pyplot as plt
    plt.imshow(img_tensor[0])
    plt.show()

# %%
for pred in predlist:
    
    if pred >= .50:
        print("male")
    
    else:
        print("female")
predlist
# Out:
# female
# female
# female
# female
# male
# female
# male
# male
# female
# female
# [array([[0.01366508]], dtype=float32),
#  array([[0.00132412]], dtype=float32),
#  array([[0.03182501]], dtype=float32),
#  array([[0.01371863]], dtype=float32),
#  array([[0.99977815]], dtype=float32),
#  array([[0.00496686]], dtype=float32),
#  array([[0.9541099]], dtype=float32),
#  array([[0.9982083]], dtype=float32),
#  array([[0.01371863]], dtype=float32),
#  array([[0.00469235]], dtype=float32)]

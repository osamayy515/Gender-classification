# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('male_and_female_small_1.h5')

# %%
import math
from random import randint
predlist =[]

for i in range(10):
    img_path = f'/home/osami/prediction data/{randint(1,102)}.jpg'
    
    from tensorflow.keras.preprocessing import image
    import numpy as np
    
    img = image.load_img(img_path, target_size=(150,150))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.
    
    predlist.append(model.predict(img_tensor))
    
    import matplotlib.pyplot as plt
    plt.imshow(img_tensor[0])
    plt.show()

# %%
for pred in predlist:
    
    if pred >= .50:
        print("male")
    
    else:
        print("female")
predlist
# Out:
# male
# female
# male
# male
# male
# male
# male
# male
# female
# female
# [array([[1.]], dtype=float32),
#  array([[5.776206e-13]], dtype=float32),
#  array([[0.99996996]], dtype=float32),
#  array([[0.99999726]], dtype=float32),
#  array([[0.99999976]], dtype=float32),
#  array([[0.9999768]], dtype=float32),
#  array([[1.]], dtype=float32),
#  array([[1.]], dtype=float32),
#  array([[5.776206e-13]], dtype=float32),
#  array([[2.5151565e-05]], dtype=float32)]
